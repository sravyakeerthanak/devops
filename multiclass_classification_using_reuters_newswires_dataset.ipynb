# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyakeerthanak/devops/blob/main/multiclass_classification_using_reuters_newswires_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 1s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 75ms/step - loss: 7.1299 - categorical_accuracy: 0.4252 - val_loss: 3.7084 - val_categorical_accuracy: 0.5350
# Epoch 2/25
# 16/16 [==============================] - 1s 52ms/step - loss: 3.3804 - categorical_accuracy: 0.5653 - val_loss: 3.1161 - val_categorical_accuracy: 0.5813
# Epoch 3/25
# 16/16 [==============================] - 1s 53ms/step - loss: 3.0309 - categorical_accuracy: 0.6132 - val_loss: 2.8699 - val_categorical_accuracy: 0.6438
# Epoch 4/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.8308 - categorical_accuracy: 0.6426 - val_loss: 2.7119 - val_categorical_accuracy: 0.6513
# Epoch 5/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.6883 - categorical_accuracy: 0.6524 - val_loss: 2.5860 - val_categorical_accuracy: 0.6725
# Epoch 6/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.5692 - categorical_accuracy: 0.6689 - val_loss: 2.4932 - val_categorical_accuracy: 0.6687
# Epoch 7/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.4796 - categorical_accuracy: 0.6737 - val_loss: 2.4001 - val_categorical_accuracy: 0.6825
# Epoch 8/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.3898 - categorical_accuracy: 0.6814 - val_loss: 2.3420 - val_categorical_accuracy: 0.6787
# Epoch 9/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.3257 - categorical_accuracy: 0.6865 - val_loss: 2.2713 - val_categorical_accuracy: 0.6862
# Epoch 10/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.2678 - categorical_accuracy: 0.6899 - val_loss: 2.2273 - val_categorical_accuracy: 0.6938
# Epoch 11/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.2148 - categorical_accuracy: 0.6936 - val_loss: 2.1705 - val_categorical_accuracy: 0.6862
# Epoch 12/25
# 16/16 [==============================] - 1s 85ms/step - loss: 2.1765 - categorical_accuracy: 0.6913 - val_loss: 2.1465 - val_categorical_accuracy: 0.6900
# Epoch 13/25
# 16/16 [==============================] - 1s 86ms/step - loss: 2.1383 - categorical_accuracy: 0.6963 - val_loss: 2.1354 - val_categorical_accuracy: 0.6825
# Epoch 14/25
# 16/16 [==============================] - 1s 66ms/step - loss: 2.1071 - categorical_accuracy: 0.6960 - val_loss: 2.0864 - val_categorical_accuracy: 0.6938
# Epoch 15/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.0805 - categorical_accuracy: 0.6986 - val_loss: 2.0591 - val_categorical_accuracy: 0.6950
# Epoch 16/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0605 - categorical_accuracy: 0.7020 - val_loss: 2.0418 - val_categorical_accuracy: 0.6963
# Epoch 17/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.0384 - categorical_accuracy: 0.6995 - val_loss: 2.0165 - val_categorical_accuracy: 0.6950
# Epoch 18/25
# 16/16 [==============================] - 1s 57ms/step - loss: 2.0148 - categorical_accuracy: 0.7030 - val_loss: 2.0051 - val_categorical_accuracy: 0.6925
# Epoch 19/25
# 16/16 [==============================] - 1s 57ms/step - loss: 2.0010 - categorical_accuracy: 0.7048 - val_loss: 2.0075 - val_categorical_accuracy: 0.6988
# Epoch 20/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9791 - categorical_accuracy: 0.7063 - val_loss: 1.9741 - val_categorical_accuracy: 0.7000
# Epoch 21/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9659 - categorical_accuracy: 0.7078 - val_loss: 1.9528 - val_categorical_accuracy: 0.7025
# Epoch 22/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9494 - categorical_accuracy: 0.7123 - val_loss: 1.9527 - val_categorical_accuracy: 0.6988
# Epoch 23/25
# 16/16 [==============================] - 1s 52ms/step - loss: 1.9366 - categorical_accuracy: 0.7143 - val_loss: 1.9324 - val_categorical_accuracy: 0.7075
# Epoch 24/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9219 - categorical_accuracy: 0.7132 - val_loss: 1.9230 - val_categorical_accuracy: 0.7050
# Epoch 25/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9167 - categorical_accuracy: 0.7128 - val_loss: 1.9119 - val_categorical_accuracy: 0.7038

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
