# %% [markdown]
# <a href="https://colab.research.google.com/github/sravyakeerthanak/devops/blob/main/Regularization_on_Multiclass_classification_using_Reuters_Newswires_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 1s 0us/step

# %%
#Each review (row) is of different size. This data needs to be made uniform.
# i.e. each reviuew (i.e. row) needs to be onehotencoded to a length of 10,000 (we have decided to have only 10000 features)
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
#create the layers
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 75ms/step - loss: 7.2667 - categorical_accuracy: 0.4514 - val_loss: 3.7943 - val_categorical_accuracy: 0.5412
# Epoch 2/25
# 16/16 [==============================] - 1s 55ms/step - loss: 3.4147 - categorical_accuracy: 0.5521 - val_loss: 3.1245 - val_categorical_accuracy: 0.6112
# Epoch 3/25
# 16/16 [==============================] - 1s 52ms/step - loss: 3.0323 - categorical_accuracy: 0.6120 - val_loss: 2.8716 - val_categorical_accuracy: 0.6413
# Epoch 4/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.8345 - categorical_accuracy: 0.6385 - val_loss: 2.7355 - val_categorical_accuracy: 0.6662
# Epoch 5/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.6908 - categorical_accuracy: 0.6568 - val_loss: 2.6011 - val_categorical_accuracy: 0.6837
# Epoch 6/25
# 16/16 [==============================] - 1s 59ms/step - loss: 2.5789 - categorical_accuracy: 0.6700 - val_loss: 2.4872 - val_categorical_accuracy: 0.6837
# Epoch 7/25
# 16/16 [==============================] - 1s 87ms/step - loss: 2.4824 - categorical_accuracy: 0.6751 - val_loss: 2.4291 - val_categorical_accuracy: 0.6925
# Epoch 8/25
# 16/16 [==============================] - 1s 88ms/step - loss: 2.4035 - categorical_accuracy: 0.6830 - val_loss: 2.3418 - val_categorical_accuracy: 0.6875
# Epoch 9/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.3366 - categorical_accuracy: 0.6871 - val_loss: 2.2847 - val_categorical_accuracy: 0.6913
# Epoch 10/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.2821 - categorical_accuracy: 0.6908 - val_loss: 2.2667 - val_categorical_accuracy: 0.6963
# Epoch 11/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.2313 - categorical_accuracy: 0.6920 - val_loss: 2.2019 - val_categorical_accuracy: 0.6925
# Epoch 12/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.1864 - categorical_accuracy: 0.6949 - val_loss: 2.1446 - val_categorical_accuracy: 0.7013
# Epoch 13/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.1558 - categorical_accuracy: 0.6932 - val_loss: 2.1097 - val_categorical_accuracy: 0.6975
# Epoch 14/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.1211 - categorical_accuracy: 0.6967 - val_loss: 2.0888 - val_categorical_accuracy: 0.6963
# Epoch 15/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.0953 - categorical_accuracy: 0.6969 - val_loss: 2.0808 - val_categorical_accuracy: 0.6925
# Epoch 16/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.0701 - categorical_accuracy: 0.6984 - val_loss: 2.0398 - val_categorical_accuracy: 0.7063
# Epoch 17/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.0494 - categorical_accuracy: 0.6987 - val_loss: 2.0205 - val_categorical_accuracy: 0.7050
# Epoch 18/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.0245 - categorical_accuracy: 0.7012 - val_loss: 2.0249 - val_categorical_accuracy: 0.7038
# Epoch 19/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0117 - categorical_accuracy: 0.7006 - val_loss: 1.9829 - val_categorical_accuracy: 0.7013
# Epoch 20/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9942 - categorical_accuracy: 0.7013 - val_loss: 1.9670 - val_categorical_accuracy: 0.7063
# Epoch 21/25
# 16/16 [==============================] - 1s 88ms/step - loss: 1.9742 - categorical_accuracy: 0.7035 - val_loss: 1.9587 - val_categorical_accuracy: 0.7125
# Epoch 22/25
# 16/16 [==============================] - 1s 88ms/step - loss: 1.9611 - categorical_accuracy: 0.7044 - val_loss: 1.9558 - val_categorical_accuracy: 0.7075
# Epoch 23/25
# 16/16 [==============================] - 1s 54ms/step - loss: 1.9408 - categorical_accuracy: 0.7090 - val_loss: 1.9314 - val_categorical_accuracy: 0.7075
# Epoch 24/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9270 - categorical_accuracy: 0.7084 - val_loss: 1.9159 - val_categorical_accuracy: 0.7100
# Epoch 25/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9152 - categorical_accuracy: 0.7086 - val_loss: 1.8998 - val_categorical_accuracy: 0.7125

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
